# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaSajjanar23/6thSem-ML-Lab/blob/main/1BM23CS209_Lab9_KMeansClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

# -----------------------------
# Step 1: Load the CSV dataset
# -----------------------------
df = pd.read_csv("iris.csv")
print("Dataset Preview:\n", df.head())

# -----------------------------
# Step 2: Use only features for clustering
# -----------------------------
X = df.drop("species", axis=1)

# -----------------------------
# Step 3: Scale the features
# -----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# -----------------------------
# Step 4: K-Means Clustering
# -----------------------------
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)

# Add cluster labels to original dataset
df["Cluster"] = kmeans.labels_
print("\nClustered Data (first 10 rows):\n", df.head(10))

# -----------------------------
# Step 5: Cluster Centers
# -----------------------------
print("\nCluster Centers (scaled features):\n", kmeans.cluster_centers_)

# -----------------------------
# Step 6: Elbow Method (Optional, without plotting)
# -----------------------------
print("\nInertia values for k=1 to 9 (Elbow Method):")
inertia = []
for k in range(1, 10):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_scaled)
    inertia.append(km.inertia_)
    print(f"k={k}, Inertia={km.inertia_}")

# -----------------------------
# Step 7: Compare clusters vs actual species
# -----------------------------
# Convert species to numeric for comparison
species_numeric, _ = pd.factorize(df["species"])

print("\nConfusion Matrix (Clusters vs Actual Species):")
cm = confusion_matrix(species_numeric, df["Cluster"])
print(cm)

print("\nClassification Report (Clusters vs Species):")
print(classification_report(species_numeric, df["Cluster"]))
# Out:
# Dataset Preview:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
# Clustered Data (first 10 rows):
#     sepal_length  sepal_width  petal_length  petal_width      species  Cluster
# 0           5.1          3.5           1.4          0.2  Iris-setosa        1
# 1           4.9          3.0           1.4          0.2  Iris-setosa        2
# 2           4.7          3.2           1.3          0.2  Iris-setosa        2
# 3           4.6          3.1           1.5          0.2  Iris-setosa        2
# 4           5.0          3.6           1.4          0.2  Iris-setosa        1
# 5           5.4          3.9           1.7          0.4  Iris-setosa        1
# 6           4.6          3.4           1.4          0.3  Iris-setosa        1
# 7           5.0          3.4           1.5          0.2  Iris-setosa        1
# 8           4.4          2.9           1.4          0.2  Iris-setosa        2
# 9           4.9          3.1           1.5          0.1  Iris-setosa        2
#
# Cluster Centers (scaled features):
#  [[ 0.57100359 -0.36600236  0.69108416  0.66322635]
#  [-0.80601877  1.33577362 -1.28618375 -1.21026347]
#  [-1.31926109 -0.34584225 -1.14482725 -1.1336954 ]]
#
# Inertia values for k=1 to 9 (Elbow Method):
# k=1, Inertia=600.0000000000003
# k=2, Inertia=223.73200573676343
# k=3, Inertia=192.03717409190025
# k=4, Inertia=114.6822160993797
# k=5, Inertia=91.29544474066981
# k=6, Inertia=81.7602613286062
# k=7, Inertia=80.98238131032987
# k=8, Inertia=68.08623905064636
# k=9, Inertia=59.38528882045365
#
# Confusion Matrix (Clusters vs Actual Species):
# [[ 0 32 18]
#  [46  0  4]
#  [50  0  0]]
#
# Classification Report (Clusters vs Species):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      50.0
#            1       0.00      0.00      0.00      50.0
#            2       0.00      0.00      0.00      50.0
#
#     accuracy                           0.00     150.0
#    macro avg       0.00      0.00      0.00     150.0
# weighted avg       0.00      0.00      0.00     150.0
